# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12,))
ax = plt.axes(projection=ccrs.PlateCarree())

# make the map global rather than have it zoom in to
# the extents of any plotted data
ax.set_global()

ax.stock_img()
ax.coastlines()
ax.gridlines(color='black', alpha=0.5, linestyle='--')

ax.tissot(facecolor='lightgray', edgecolor='black', alpha=0.85, rad_km=1000)

plt.savefig('tissot.platecarree.1000km.png', bbox_inches='tight')
# Out:
# /scratch/itpe/conda/envs/cartopy-tutorial-2018/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x7f0c0007eaf0> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
