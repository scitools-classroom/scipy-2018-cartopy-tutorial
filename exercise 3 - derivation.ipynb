# %% [markdown]
# Goal is to produce maps that can be printed off to play with projections

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
# def equidistant_lines(ax):
#     ax.

import cartopy.geodesic
geod = cartopy.geodesic.Geodesic()

start = [-60, 40]
end = [60, 40]


import numpy as np


npts = 50
xs = np.linspace(start[0], end[0], npts)
ys = np.linspace(start[1], end[1], npts)
points = np.vstack([xs, ys]).T
points.shape



import shapely.geometry as sgeom

gc = sgeom.LineString(points[(0, -1), :])
# rhumb = sgeom.LineString(points)


def decorate(ax):
    ax.gridlines()
    ax.coastlines()
    ax.tissot(alpha=0.35, rad_km=800, facecolor='orange')
    
    ax.add_geometries([gc], ccrs.Geodetic(), edgecolor='red', facecolor='none', linewidth=2)
#     ax.add_geometries([rhumb], ccrs.Geodetic(), edgecolor='blue', facecolor='none', linewidth=2)
# gc

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.Robinson())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11daa1eb8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11daa1ca8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.PlateCarree())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x10e6aff68> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x10e6aff10> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.NorthPolarStereo())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d838150> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d8380f8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.LambertAzimuthalEqualArea())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d66de60> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d66de08> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %% [markdown]
# Now try to draw the same features on the following map.
# What projection do you think this might be?

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.LambertConformal())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d4143b8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d414360> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
# TODO: The cache doesn't seem to care about the threshold...
# Try running this with one threshold, then change it to another to observe.

class Ortho(ccrs.Orthographic):
    @property
    def threshold(self):
        return self._threshold / 60.
    
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=Ortho())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d1e1fc0> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d1f87d8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.InterruptedGoodeHomolosine())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11decc410> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11decc3b8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.Miller())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11ded9990> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11ded9938> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.Gnomonic())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11decc2b0> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11c7deaf0> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.Sinusoidal())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d1f8a98> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d1f8990> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.AlbersEqualArea())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d414678> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11d414620> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.Mercator())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11df13150> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11df13258> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
plt.figure(figsize=(12, 12))
ax = plt.axes(projection=ccrs.Mollweide())
decorate(ax)
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11e1f5258> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11e1f5200> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
projections = [ccrs.Robinson(), ccrs.PlateCarree(), ccrs.Mercator(), ccrs.AlbersEqualArea(), ccrs.Sinusoidal(),
               ccrs.Miller(), ccrs.InterruptedGoodeHomolosine(), Ortho(),
               ccrs.LambertAzimuthalEqualArea(), ccrs.NorthPolarStereo(), ccrs.Mercator(), ccrs.Gnomonic()]

# %%
conformal = [ccrs.LambertConformal(), ccrs.NorthPolarStereo(), ccrs.Mercator()]

equal_area = [ccrs.Sinusoidal(), ccrs.InterruptedGoodeHomolosine(),
              ccrs.LambertAzimuthalEqualArea(), ccrs.AlbersEqualArea()]
equidistant_meridian = [ccrs.PlateCarree()]
equidistant_parallels = [ccrs.Sinusoidal()]
great_circle_straight_line = [ccrs.Gnomonic()]
compromise = [ccrs.Robinson(), ccrs.Miller()]

# %%
from matplotlib import pyplot as plot
from matplotlib.backends.backend_pdf import PdfPages
 
# The PDF document
pdf_pages = PdfPages('projections.pdf')

proj_per_page = 3
n_pages = max([len(projections) // proj_per_page, 1])
for i in range(n_pages):
    # Create a figure instance (ie. a new page)
    fig = plot.figure(figsize=(8.27, 11.69), dpi=100)

    page_projections = projections[proj_per_page*i:(proj_per_page*i + proj_per_page)]
    for j, proj in enumerate(page_projections):
        # Plot whatever you wish to plot
        ax = fig.add_subplot(proj_per_page, 1, j + 1, projection=proj)
        decorate(ax)

    # Done with the page
    pdf_pages.savefig(fig)

# Write the PDF document to the disk
pdf_pages.close()
# Out:
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11e1e9048> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11e1e9f10> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11e2465c8> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# /Users/pelson/dev/scitools/cartopy/lib/cartopy/mpl/geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x11e246258> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))
# ...
